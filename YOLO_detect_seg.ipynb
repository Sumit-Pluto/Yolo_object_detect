# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.1/800.1 kB 9.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
# %cd /content/drive/MyDrive/car_truck_sign_datasets

# !yolo task=detect mode=train model=/content/drive/MyDrive/yolov5m.pt data="/content/drive/MyDrive/car_truck_sign_datasets/data.yaml" epochs=25 imgsz=256 batch=4 plots=True

#give the best.pt model weight
# Out:
# /content/drive/MyDrive/car_truck_sign_datasets
# PRO TIP 💡 Replace 'model=/content/drive/MyDrive/yolov5m.pt' with new 'model=/content/drive/MyDrive/yolov5mu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 48.2M/48.2M [00:00<00:00, 210MB/s]
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model= /content/drive/MyDrive/car_truck_sign_datasets/runs/detect/train/weights/best.pt source='/content/drive/MyDrive/car_truck_sign_datasets/test/images' imgsz=320
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5m summary (fused): 248 layers, 25047532 parameters, 0 gradients, 64.0 GFLOPs
#
# image 1/50 /content/drive/MyDrive/car_truck_sign_datasets/test/images/screenshot_0_1653936310-7362761_jpg.rf.19f1f1704da527bd565914aebef1e6d1.jpg: 320x320 (no detections), 14.8ms
# image 2/50 /content/drive/MyDrive/car_truck_sign_datasets/test/images/screenshot_0_1653936437-140043_jpg.rf.e2ea5f8546a15066065b5d9587228321.jpg: 320x320 1 car, 14.7ms
# image 3/50 /content/drive/MyDrive/car_truck_sign_datasets/test/images/screenshot_0_1653936743-152593_jpg.rf.7153fdf4770904c739d916937b268c45.jpg: 320x320 (no detections), 14.8ms
# image 4/50 /content/drive/MyDrive/car_truck_sign_datasets/test/images/screenshot_0_1653937118-4471226_jpg.rf.1e5bb6e240df348952619974713c303c.jpg: 320x320 1 car, 1 truck, 14.7ms
# ...

# %%
## below code is for yolo segmentation model training

# %%
# !yolo task=segment mode=train model= data=" " epochs=25 imgsz=256 batch=4 plots=True # model for segmentation task should be yolo seg model
# Out:
# Ultralytics YOLOv8.2.3 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
